# %%
# %reload_ext kedro.ipython
# Out:
# [04/21/26 15:00:06] INFO     Registered line magic '%reload_kedro'                                   ]8;id=922785;file://C:\Users\alvar\AppData\Local\Programs\Python\Python312\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=764531;file://C:\Users\alvar\AppData\Local\Programs\Python\Python312\Lib\site-packages\kedro\ipython\__init__.py#64\64]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=607603;file://C:\Users\alvar\AppData\Local\Programs\Python\Python312\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=596037;file://C:\Users\alvar\AppData\Local\Programs\Python\Python312\Lib\site-packages\kedro\ipython\__init__.py#66\66]8;;\
# ...

# %%
df_country = context.catalog.load('country')
print(df_country.head())
# Out:
# [04/21/26 14:47:32] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=697950;file://C:\Users\alvar\AppData\Local\Programs\Python\Python312\Lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=306098;file://C:\Users\alvar\AppData\Local\Programs\Python\Python312\Lib\site-packages\kedro_telemetry\plugin.py#242\242]8;;\
#                              the product. No personal data or IP addresses are stored on our side. To
#                              opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK` environment
#                              variables, or create a `.telemetry` file in the current working
#                              directory with the contents `consent: false`. To hide this message,
#                              explicitly grant or deny consent. Read more at
#                              https://docs.kedro.org/en/stable/about/telemetry/
# ...
