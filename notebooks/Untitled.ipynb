# %%
# %reload_ext kedro.ipython
# Out:
# [04/22/26 02:00:35] INFO     Registered line magic '%reload_kedro'                                   ]8;id=378762;file:///Users/unk/Desktop/semestre5/kedro/analisis_y_ml_ds_football/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=378763;file:///Users/unk/Desktop/semestre5/kedro/analisis_y_ml_ds_football/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py#64\64]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=378768;file:///Users/unk/Desktop/semestre5/kedro/analisis_y_ml_ds_football/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=378769;file:///Users/unk/Desktop/semestre5/kedro/analisis_y_ml_ds_football/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py#66\66]8;;\
# ...

# %%
df_country = context.catalog.load('country')
print(df_country.head())
# Out:
# [04/22/26 02:02:59] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=378822;file:///Users/unk/Desktop/semestre5/kedro/analisis_y_ml_ds_football/.venv/lib/python3.12/site-packages/kedro_telemetry/plugin.py\plugin.py]8;;\:]8;id=378823;file:///Users/unk/Desktop/semestre5/kedro/analisis_y_ml_ds_football/.venv/lib/python3.12/site-packages/kedro_telemetry/plugin.py#242\242]8;;\
#                              the product. No personal data or IP addresses are stored on our side. To
#                              opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK` environment
#                              variables, or create a `.telemetry` file in the current working
#                              directory with the contents `consent: false`. To hide this message,
#                              explicitly grant or deny consent. Read more at
#                              https://docs.kedro.org/en/stable/about/telemetry/
# ...
